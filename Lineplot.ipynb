# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

dataframe = pd.DataFrame(np.random.randint(1, 100, size=(100, 2), dtype=int))
dataframe.columns = ["X", "Y"]
dataframe.drop_duplicates("X", inplace=True)
dataframe.sort_values("X", inplace=True)
plt.plot(dataframe["X"], dataframe["Y"])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Line plot")
plt.savefig("Lineplot_1.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2739c17c82c7> in <module>
#      11 plt.ylabel("Y")
#      12 plt.title("Line plot")
# ---> 13 plt.cool(1)
#      14 plt.savefig("Lineplot_1.png")
#
# TypeError: cool() takes 0 positional arguments but 1 was given
